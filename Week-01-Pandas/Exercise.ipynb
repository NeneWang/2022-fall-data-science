# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
READFROM="data/listings.csv"
df = pd.read_csv(READFROM)

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a368b532c1b5> in <module>
#       1 # Load data here
#       2 READFROM="data/listings.csv"
# ----> 3 df = pd.read_csv(READFROM)
#       4
#       5 df.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 

comparator = df['price'] < 100
# len(list(filter(lambda x: x==True, comparator)))
len(df[comparator])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35bf0ed5a043> in <module>
#       1 # 1. How many listings are there with a price less than 100?
#       2
# ----> 3 comparator = df['price'] < 100
#       4 # len(list(filter(lambda x: x==True, comparator)))
#       5 len(df[comparator])
#
# NameError: name 'df' is not defined

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.


# gb = df.groupby('neighbourhood_group')
# dir(gb)

brooklyn_comparator = df["neighbourhood_group"] == "Brooklyn"
# print(brooklyn_comparator)

# count_brooklyn = len(list(filter(lambda x: x==True, brooklyn_comparator)))
count_brooklyn = len(df[brooklyn_comparator])
print("count of listings in Brooklyn", count_brooklyn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ec21a20b8b98> in <module>
#       6 # dir(gb)
#       7
# ----> 8 brooklyn_comparator = df["neighbourhood_group"] == "Brooklyn"
#       9 # print(brooklyn_comparator)
#      10
#
# NameError: name 'df' is not defined

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

in_brooklyn = df["neighbourhood_group"] == "Brooklyn"

less_100 = df["price"] < 100

# Select all data that meets condition 1 or condition 2
# df[ in_brooklyn & less_100]

len(df[in_brooklyn & less_100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-803793afcb6b> in <module>
#       1 # 3. Find how many listings there are in Brooklyn with a price less than 100.
#       2
# ----> 3 in_brooklyn = df["neighbourhood_group"] == "Brooklyn"
#       4
#       5 less_100 = df["price"] < 100
#
# NameError: name 'df' is not defined

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
host_names = ["Michael", "David", "John", "Daniel"]

chosen_ones = df.host_name.isin(host_names)
print(len(df[chosen_ones]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a86172e295b8> in <module>
#       2 host_names = ["Michael", "David", "John", "Daniel"]
#       3
# ----> 4 chosen_ones = df.host_name.isin(host_names)
#       5 print(len(df[chosen_ones]))
#
# NameError: name 'df' is not defined

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 
def adjust_price_william(x):
#     print(x)
    if "Williamsburg" == str(x):
        return 100
    else:
        return 0
    
df["adjusted_price"] = df["price"]
df['adjusted_price'] += df['neighbourhood'].apply(adjust_price_william)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1d6397bf3503> in <module>
#       8         return 0
#       9
# ---> 10 df["adjusted_price"] = df["price"]
#      11 df['adjusted_price'] += df['neighbourhood'].apply(adjust_price_william)
#      12
#
# NameError: name 'df' is not defined

# %%
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-61c774354124> in <module>
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

# shared_type = df["room_type"] == "Shared room"
# private_type = df["room_type"] == "Private Room"

class ROOM():
    SHARED = "Shared room"
    PRIVATE = "Private room"

def getPercentage(dataFrame, category):
    type_cond = df["room_type"] == category
    return len(dataFrame[type_cond])/len(dataFrame)

print(f"Percentage Private: {getPercentage(df, ROOM.PRIVATE)}\nShared: {getPercentage(df, ROOM.SHARED)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e7f5ad81f3cf> in <module>
#      12     return len(dataFrame[type_cond])/len(dataFrame)
#      13
# ---> 14 print(f"Percentage Private: {getPercentage(df, ROOM.PRIVATE)}\nShared: {getPercentage(df, ROOM.SHARED)}")
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.

gb = df.groupby("neighbourhood_group")
print(gb.size())
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 


gb = df.groupby("neighbourhood_group")
print(gb["price"].mean())
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 


gb = df.groupby("neighbourhood_group")
print(gb["price"].agg(["min", "max"]))
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.


gb = df.groupby("room_type")
print(gb["price"].mean())
# Out:
# room_type
# Entire home/apt    199.395950
# Hotel room         275.015075
# Private room        91.453084
# Shared room         87.063830
# Name: price, dtype: float64

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.



gb = df.groupby("room_type")
print(gb["price"].agg(["count", "min", "max", "mean", "median", "std"]))
# Out:
#                  count  min    max        mean  median         std
# room_type
# Entire home/apt  23998    0  10000  199.395950     150  337.657116
# Hotel room         398    0   2211  275.015075     192  301.658021
# Private room     21144   10  10000   91.453084      65  282.450148
# Shared room        987   10  10000   87.063830      46  354.048373

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
# Load data here
LISTINGSREAD="data/n_listings.csv"
dflisting = pd.read_csv(LISTINGSREAD, sep=';')

PRICESREAD="data/prices.csv"
priceslisting = pd.read_csv(PRICESREAD)

# priceslisting.head()
dflisting.head()

# neighbourhood_group

new_df = pd.merge(dflisting, priceslisting, on="neighbourhood_group")
print(new_df.head())
# #
# Out:
#   neighbourhood_group  n_listings   mean_price
# 0               Bronx        1183    92.751479
# 1            Brooklyn       18632   120.225258
# 2           Manhattan       20580   191.880466

# %%
priceslisting.head()
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx    92.751479
# 1            Brooklyn   120.225258
# 2           Manhattan   191.880466
# 3              Queens    99.754965
# 4       Staten Island   110.947214

# %%
dflisting.head()
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# 2. Do join that keeps all the records for each table.

new_df = pd.merge(dflisting, priceslisting, on="neighbourhood_group", how='outer')
print(new_df.head())
# Out:
#   neighbourhood_group  n_listings   mean_price
# 0               Bronx      1183.0    92.751479
# 1            Brooklyn     18632.0   120.225258
# 2           Manhattan     20580.0   191.880466
# 3          LongIsland      4121.0          NaN
# 4              Queens         NaN    99.754965

# %%
save_as = 'my-data-file.csv'

# This is the method you use, DONT FORGET INDEX=FALSE!
# Index are the numbers
new_df.to_csv(save_as, index=False)

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
FILEPATH_GRAMMY="data/grammys.csv"
df = pd.read_csv(FILEPATH_GRAMMY, sep=",")
df.head(50)
# Out:
#     year                                           category  \
# 0   1959                                  Album of the Year
# 1   1959                                   Best Album Cover
# 2   1959                                   Best Arrangement
# 3   1959  Best Classical Performance - Chamber Music (in...
# 4   1959  Best Classical Performance - Instrumentalist (...
# 5   1959  Best Classical Performance - Instrumentalist (...
# 6   1959  Best Classical Performance - Instrumentalist (...
# 7   1959    Best Classical Performance - Operatic or Choral
# 8   1959             Best Classical Performance - Orchestra
# 9   1959  Best Classical Performance - Vocal Soloist (wi...
# 10  1959                            Best Comedy Performance
# 11  1959                 Best Country & Western Performance
# 12  1959               Best Country and Western Performance
# 13  1959                 Best Engineered Record (Classical)
# 14  1959             Best Engineered Record - Non-Classical
# 15  1959                      Best Instrumental Arrangement
# 16  1959                      Best Instrumental Composition
# 17  1959                       Best Jazz Performance, Group
# 18  1959                  Best Jazz Performance, Individual
# 19  1959  Best Musical Composition First Recorded and Re...
# 20  1959          Best Original Cast Album (Broadway or TV)
# 21  1959                   Best Performance by a Dance Band
# 22  1959        Best Performance by a Vocal Group or Chorus
# 23  1959  Best Performance by an Orchestra - for Other T...
# 24  1959       Best Performance, Documentary or Spoken Word
# 25  1959       Best R&B Vocal Performance by a Duo or Group
# 26  1959                        Best Recording for Children
# 27  1959                    Best Rhythm & Blues Performance
# 28  1959  Best Sound Track Album, Dramatic Picture Score...
# 29  1959  Best Soundtrack Album, Dramatic Picture Score ...
# 30  1959  Best Soundtrack Album, Dramatic Picture Score ...
# 31  1959  Best Soundtrack Album, Dramatic Picture Score ...
# 32  1959                     Best Vocal Performance, Female
# 33  1959                       Best Vocal Performance, Male
# 34  1959                                 Record of the Year
# 35  1959                                   Song of the Year
# 36  1961                                  Album of the Year
# 37  1961                                   Best Album Cover
# 38  1961                    Best Album Created For Children
# 39  1961                                   Best Arrangement
# 40  1961                    Best Classical Opera Production
# 41  1961  Best Classical Performance - Vocal Or Instrume...
# 42  1961  Best Classical Performance- Choral (Including ...
# 43  1961  Best Classical Performance- Concerto Or Instru...
# 44  1961  Best Classical Performance- Instrumental Soloi...
# 45  1961              Best Classical Performance- Orchestra
# 46  1961          Best Classical Performance- Vocal Soloist
# 47  1961                  Best Comedy Performance - Musical
# 48  1961              Best Comedy Performance - Spoken Word
# 49  1961            Best Contemporary Classical Composition
#
#                                               nominee  \
# 0                          The Music from Peter Gunn.
# 1                                     Only the Lonely
# 2                           The Music From Peter Gunn
# 3                              Beethoven: Quartet 130
# 4                              Segovia Golden Jubilee
# 5                              Segovia Golden Jubilee
# 6   Tchaikovsky: Piano Concerto No. 1 In B Flat Mi...
# 7                                            Virtuoso
# 8                                   Gaiete Parisienne
# 9                                    Operatic Recital
# 10                                  The Chipmunk Song
# 11                                         Tom Dooley
# 12                                        Tom Dooley.
# 13                        Duets with a Spanish Guitar
# 14                                  The Chipmunk Song
# 15                         The Music from Peter Gunn.
# 16                               Cross Country Suite.
# 17                                             Basie.
# 18  Ella Fitzgerald Sings the Duke Ellington Songb...
# 19                                Cross Country Suite
# 20                                      The Music Man
# 21                                              Basie
# 22                               That Old Black Magic
# 23                          Billy May's Big Fat Brass
# 24                 The Best Of The Stan Freberg Shows
# 25                                            Tequila
# 26        The Chipmunk Song (Christmas Don't Be Late)
# 27                                            Tequila
# 28                                               Gigi
# 29                                               Gigi
# 30                                    I Want to Live!
# 31                       The Bridge on the River Kwai
# 32                                    Ella Fitzgerald
# 33                                         Perry Como
# 34                   Nel Blu Dipinto di Blu (Volare).
# 35                   Nel Blu Dipinto di Blu (Volare).
# 36                The Button-Down Mind of Bob Newhart
# 37                                    Latin A La Lee.
# 38                 Let's All Sing With The Chipmunks.
# 39                                         Mr. Lucky.
# 40                                 Puccini: Turandot.
# 41                     Conversations With The Guitar.
# 42                                   Handel: Messiah.
# 43            Brahms: Piano Concerto No. 2 In B Flat.
# 44           The Spanish Guitars Of Laurindo Almeida.
# 45  Bartók: Music For Strings, Percussion And Cele...
# 46        A Program Of Song - Leontyne Price Recital.
# 47             Jonathan And Darlene Edwards In Paris.
# 48                The Button-Down Mind Strikes Back!.
# 49  Copland: Orchestral Suite From Tender Land Suite.
#
#                                               workers  winner
# 0                                       Henry Mancini    True
# 1                        Frank Sinatra (art director)    True
# 2                     Henry Mancini (artist/arranger)    True
# 3   The Hollywood String Quartet, Paul Shure (arti...    True
# 4                                      Andrés Segovia    True
# 5                             Andrés Segovia (artist)    True
# 6                        Van Cliburn (piano) (artist)    True
# 7                      Robert Wagner (choir director)    True
# 8                  Felix Slatkin (conductor) (artist)    True
# 9                   Renata Tebaldi (soprano) (artist)    True
# 10                          Ross Bagdasarian (artist)    True
# 11                         The Kingston Trio (artist)    True
# 12                                  The Kingston Trio    True
# 13   Laurindo Almeida, Salli Terri, Sherwood Hall III    True
# 14  Ross Bagdasarian (as David Seville), Ted Keep ...    True
# 15                                      Henry Mancini    True
# 16                                      Nelson Riddle    True
# 17                                        Count Basie    True
# 18                                    Ella Fitzgerald    True
# 19                    Nelson Riddle (artist/composer)    True
# 20  Robert Preston, Barbara Cook, David Burns, Edd...    True
# 21                               Count Basie (artist)    True
# 22                           Keely Smith, Louis Prima    True
# 23                                          Billy May    True
# 24                            Stan Freberg (narrator)    True
# 25  The Champs, Gene Alden, Buddy Bruce, Dave Burg...    True
# 26                                   Ross Bagdasarian    True
# 27                                The Champs (artist)    True
# 28                              André Previn (artist)    True
# 29                                       André Previn    True
# 30                                      Johnny Mandel   False
# 31                                     Malcolm Arnold   False
# 32                                                NaN    True
# 33                                                NaN    True
# 34                                   Domenico Modugno    True
# 35                                   Domenico Modugno    True
# 36                                        Bob Newhart    True
# 37  Marvin Schwartz (art director), Peggy Lee (art...    True
# 38                                   Ross Bagdasarian    True
# 39                    Henry Mancini (artist/arranger)    True
# 40  Erich Leinsdorf (artist), Rome Opera Orchestra...    True
# 41                          Laurindo Almeida (artist)    True
# 42  Royal Philharmonic Orchestra (artists), Royal ...    True
# 43  Svyatoslav Richter (artist), Chicago Symphony ...    True
# 44                          Laurindo Almeida (artist)    True
# 45               Chicago Symphony Orchestra (artists)    True
# 46                            Leontyne Price (artist)    True
# 47         Paul Weston (artist), Jo Stafford (artist)    True
# 48                                        Bob Newhart    True
# 49                           Aaron Copland (composer)    True

# %%
#  1. Who was won Album of the Year in 2016?


cond_year = df["year"] == 2016
cond_category = df["category"] == "Album of the Year"
cond_winner = df["winner"] == True



df[cond & cond_winner & cond_category]
# Out:
#       year           category nominee  \
# 5505  2016  Album of the Year   1989.
#
#                                                 workers  winner
# 5505  Taylor Swift (artist/producer), Jack Antonoff ...    True

# %%
# 2. Who won Best Rap Album in 2009?

cond_year = df["year"] == 2009
cond_category = df["category"] == "Best Rap Album"
cond_winner = df["winner"] == True



df[cond & cond_winner & cond_category]
# Out:
#       year        category               nominee         workers  winner
# 5596  2016  Best Rap Album  To Pimp a Butterfly.  Kendrick Lamar    True

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

cond_nominee = df["workers"] == "Kendrick Lamar"
cond_winner = df["winner"] == True

print(f"Awards Kendrick was nominated for: {df[cond_nominee].shape[0] }\nAwards won: ")

df[cond_winner & cond_nominee]
# Out:
# Awards Kendrick was nominated for: 6
# Awards won:
#       year              category               nominee         workers  winner
# 5448  2015  Best Rap Performance                    i.  Kendrick Lamar    True
# 5596  2016        Best Rap Album  To Pimp a Butterfly.  Kendrick Lamar    True
# 5599  2016  Best Rap Performance              Alright.  Kendrick Lamar    True
# 6003  2018  Best Rap Performance               HUMBLE.  Kendrick Lamar    True
